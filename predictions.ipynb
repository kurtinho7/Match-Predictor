# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col= 0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2024-08-17  12:30  Premier League  Matchweek 1  Sat  Away      W  2.0  0.0
# 1  2024-08-25  16:30  Premier League  Matchweek 2  Sun  Home      W  2.0  0.0
# 2  2024-09-01  16:00  Premier League  Matchweek 3  Sun  Away      W  3.0  0.0
# 3  2024-09-14  15:00  Premier League  Matchweek 4  Sat  Home      L  0.0  1.0
# 5  2024-09-21  15:00  Premier League  Matchweek 5  Sat  Home      W  3.0  0.0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0     Ipswich Town  ...  Match Report    NaN  18.0   5.0  14.8  0.0  0     0
# 1        Brentford  ...  Match Report    NaN  19.0   8.0  13.6  1.0  0     0
# 2   Manchester Utd  ...  Match Report    NaN  11.0   3.0  13.4  0.0  0     0
# 3  Nott'ham Forest  ...  Match Report    NaN  14.0   5.0  14.9  0.0  0     0
# 5      Bournemouth  ...  Match Report    NaN  19.0  12.0  16.6  0.0  0     0
#
#   season       team
# 0   2025  Liverpool
# 1   2025  Liverpool
# 2   2025  Liverpool
# 3   2025  Liverpool
# 5   2025  Liverpool
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (2200, 28)

# %%
38 * 20 * 3
# Out:
# 2280

# %%
matches["team"].value_counts()
# Out:
# team
# Liverpool                   110
# Arsenal                     110
# Newcastle United            110
# Manchester City             110
# Chelsea                     110
# Nottingham Forest           110
# Aston Villa                 110
# Fulham                      110
# Brighton and Hove Albion    110
# Bournemouth                 110
# Brentford                   110
# Crystal Palace              110
# Wolverhampton Wanderers     110
# Manchester United           110
# Everton                     110
# Tottenham Hotspur           110
# West Ham United             110
# Leicester City               72
# Southampton                  72
# Luton Town                   38
# Sheffield United             38
# Burnley                      38
# Leeds United                 38
# Ipswich Town                 34
# Name: count, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     60
# Matchweek 2     60
# Matchweek 3     60
# Matchweek 4     60
# Matchweek 5     60
# Matchweek 6     60
# Matchweek 7     60
# Matchweek 8     60
# Matchweek 9     60
# Matchweek 10    60
# Matchweek 11    60
# Matchweek 12    60
# Matchweek 13    60
# Matchweek 14    60
# Matchweek 16    60
# Matchweek 17    60
# Matchweek 18    60
# Matchweek 19    60
# Matchweek 20    60
# Matchweek 21    60
# Matchweek 22    60
# Matchweek 23    60
# Matchweek 24    60
# Matchweek 15    60
# Matchweek 25    60
# Matchweek 29    60
# Matchweek 26    60
# Matchweek 27    60
# Matchweek 28    60
# Matchweek 30    60
# Matchweek 31    60
# Matchweek 32    60
# Matchweek 33    60
# Matchweek 34    60
# Matchweek 35    40
# Matchweek 36    40
# Matchweek 37    40
# Matchweek 38    40
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype(int)

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype(int)

# %%
from sklearn.ensemble
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 5  2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      L  1.0
# 43 2023-05-08  20:00  Premier League  Matchweek 35  Mon  Away      L  3.0
# 44 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home      L  0.0
# 45 2023-05-21  14:00  Premier League  Matchweek 37  Sun  Away      L  1.0
# 46 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      D  4.0
#
#      ga         opponent  ...   fk  pk  pkatt  season         team venue_code  \
# 0   0.0     Ipswich Town  ...  0.0   0      0    2025    Liverpool          0
# 1   0.0        Brentford  ...  1.0   0      0    2025    Liverpool          1
# 2   0.0   Manchester Utd  ...  0.0   0      0    2025    Liverpool          0
# 3   1.0  Nott'ham Forest  ...  0.0   0      0    2025    Liverpool          1
# 5   0.0      Bournemouth  ...  0.0   0      0    2025    Liverpool          1
# ..  ...              ...  ...  ...  ..    ...     ...          ...        ...
# 42  3.0    Newcastle Utd  ...  0.0   0      0    2023  Southampton          0
# 43  4.0  Nott'ham Forest  ...  0.0   1      1    2023  Southampton          0
# 44  2.0           Fulham  ...  0.0   0      0    2023  Southampton          1
# 45  3.0         Brighton  ...  1.0   0      0    2023  Southampton          0
# 46  4.0        Liverpool  ...  1.0   0      0    2023  Southampton          1
#
#    opp_code hour day_code  target
# 0        10   12        5       1
# 1         3   16        6       1
# 2        16   16        6       1
# 3        18   15        5       0
# 5         2   15        5       1
# ..      ...  ...      ...     ...
# 42       17   14        6       0
# 43       18   20        0       0
# 44        9   15        5       0
# 45        4   14        6       0
# 46       13   16        6       0
#
# [2200 rows x 33 columns]

# %%
# %pip install --upgrade scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\hymys\onedrive\desktop\match predictions\.venv\lib\site-packages (from scikit-learn) (2.2.5)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.1 MB 5.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/11.1 MB 5.3 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.1 MB 5.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.1 MB 5.9 MB/s eta 0:00:02
#    -------------------- ------------------- 5.8/11.1 MB 5.8 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.1 MB 5.8 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.1 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.1 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 5.8 MB/s eta 0:00:00
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.15.2-cp311-cp311-win_amd64.whl (41.2 MB)
#    ---------------------------------------- 0.0/41.2 MB ? eta -:--:--
#    - -------------------------------------- 1.0/41.2 MB 5.0 MB/s eta 0:00:08
#    -- ------------------------------------- 2.4/41.2 MB 5.8 MB/s eta 0:00:07
#    --- ------------------------------------ 3.7/41.2 MB 5.9 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.0/41.2 MB 5.9 MB/s eta 0:00:07
#    ----- ---------------------------------- 6.0/41.2 MB 6.1 MB/s eta 0:00:06
#    ------- -------------------------------- 7.3/41.2 MB 6.0 MB/s eta 0:00:06
#    -------- ------------------------------- 8.4/41.2 MB 6.0 MB/s eta 0:00:06
#    -------- ------------------------------- 9.2/41.2 MB 5.6 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.5/41.2 MB 5.6 MB/s eta 0:00:06
#    ----------- ---------------------------- 11.8/41.2 MB 5.8 MB/s eta 0:00:06
#    ------------ --------------------------- 13.1/41.2 MB 5.8 MB/s eta 0:00:05
#    ------------- -------------------------- 14.4/41.2 MB 5.8 MB/s eta 0:00:05
#    --------------- ------------------------ 15.5/41.2 MB 5.9 MB/s eta 0:00:05
#    ---------------- ----------------------- 16.8/41.2 MB 5.8 MB/s eta 0:00:05
#    ----------------- ---------------------- 17.8/41.2 MB 5.8 MB/s eta 0:00:05
#    ------------------ --------------------- 19.1/41.2 MB 5.8 MB/s eta 0:00:04
#    ------------------- -------------------- 20.2/41.2 MB 5.8 MB/s eta 0:00:04
#    -------------------- ------------------- 21.5/41.2 MB 5.8 MB/s eta 0:00:04
#    --------------------- ------------------ 22.3/41.2 MB 5.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 23.6/41.2 MB 5.7 MB/s eta 0:00:04
#    ----------------------- ---------------- 24.6/41.2 MB 5.7 MB/s eta 0:00:03
#    ------------------------- -------------- 26.0/41.2 MB 5.7 MB/s eta 0:00:03
#    -------------------------- ------------- 27.0/41.2 MB 5.7 MB/s eta 0:00:03
#    --------------------------- ------------ 28.3/41.2 MB 5.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 29.6/41.2 MB 5.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 30.7/41.2 MB 5.7 MB/s eta 0:00:02
#    ------------------------------- -------- 32.2/41.2 MB 5.7 MB/s eta 0:00:02
#    -------------------------------- ------- 33.3/41.2 MB 5.7 MB/s eta 0:00:02
#    --------------------------------- ------ 34.6/41.2 MB 5.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 35.7/41.2 MB 5.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 37.0/41.2 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 38.0/41.2 MB 5.7 MB/s eta 0:00:01
#    -------------------------------------- - 39.3/41.2 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  40.4/41.2 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.2 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 41.2/41.2 MB 5.6 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2025-01-01']

# %%
test = matches[matches["date"] > '2025-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           139  44
# 1            71  48

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.5217391304347826

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Liverpool")

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 5  2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 47 2023-05-03  20:00  Premier League  Matchweek 28  Wed  Home      W  1.0
# 48 2023-05-06  17:30  Premier League  Matchweek 35  Sat  Home      W  1.0
# 49 2023-05-15  20:00  Premier League  Matchweek 36  Mon  Away      W  3.0
# 50 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D  1.0
# 51 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      D  4.0
#
#      ga         opponent  ...   fk  pk  pkatt  season       team venue_code  \
# 0   0.0     Ipswich Town  ...  0.0   0      0    2025  Liverpool          0
# 1   0.0        Brentford  ...  1.0   0      0    2025  Liverpool          1
# 2   0.0   Manchester Utd  ...  0.0   0      0    2025  Liverpool          0
# 3   1.0  Nott'ham Forest  ...  0.0   0      0    2025  Liverpool          1
# 5   0.0      Bournemouth  ...  0.0   0      0    2025  Liverpool          1
# ..  ...              ...  ...  ...  ..    ...     ...        ...        ...
# 47  0.0           Fulham  ...  0.0   1      1    2023  Liverpool          1
# 48  0.0        Brentford  ...  0.0   0      0    2023  Liverpool          1
# 49  0.0   Leicester City  ...  1.0   0      0    2023  Liverpool          0
# 50  1.0      Aston Villa  ...  0.0   0      0    2023  Liverpool          1
# 51  4.0      Southampton  ...  0.0   0      0    2023  Liverpool          0
#
#    opp_code hour day_code  target
# 0        10   12        5       1
# 1         3   16        6       1
# 2        16   16        6       1
# 3        18   15        5       0
# 5         2   15        5       1
# ..      ...  ...      ...     ...
# 47        9   20        2       1
# 48        3   17        5       1
# 49       12   20        0       1
# 50        1   15        5       0
# 51       20   16        6       0
#
# [110 rows x 33 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  9.0
# 5  2022-08-31  20:00  Premier League   Matchweek 5  Wed  Home      W  2.0
# 6  2022-09-03  12:30  Premier League   Matchweek 6  Sat  Away      D  0.0
# 9  2022-10-01  15:00  Premier League   Matchweek 9  Sat  Home      D  3.0
# 11 2022-10-09  16:30  Premier League  Matchweek 10  Sun  Away      L  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 47 2025-04-02  20:00  Premier League  Matchweek 30  Wed  Home      W  1.0
# 48 2025-04-06  14:00  Premier League  Matchweek 31  Sun  Away      L  2.0
# 49 2025-04-13  14:00  Premier League  Matchweek 32  Sun  Home      W  2.0
# 50 2025-04-20  16:30  Premier League  Matchweek 33  Sun  Away      W  1.0
# 51 2025-04-27  16:30  Premier League  Matchweek 34  Sun  Home      W  5.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 4   0.0     Bournemouth  ...         5       1    1.333333    1.666667
# 5   1.0   Newcastle Utd  ...         2       1    3.666667    1.000000
# 6   0.0         Everton  ...         5       0    4.000000    1.000000
# 9   3.0        Brighton  ...         5       0    3.666667    0.333333
# 11  3.0         Arsenal  ...         6       0    1.666667    1.333333
# ..  ...             ...  ...       ...     ...         ...         ...
# 47  0.0         Everton  ...         2       1    2.333333    0.333333
# 48  3.0          Fulham  ...         6       0    2.000000    0.333333
# 49  1.0        West Ham  ...         6       1    2.000000    1.333333
# 50  0.0  Leicester City  ...         6       1    1.666667    1.333333
# 51  1.0       Tottenham  ...         6       1    1.666667    1.333333
#
#    sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 4   17.333333    4.000000    14.733333   0.000000   0.000000       0.000000
# 5   20.000000    7.000000    14.466667   0.000000   0.000000       0.000000
# 6   19.666667    7.666667    14.600000   0.000000   0.000000       0.000000
# 9   21.666667    8.666667    14.166667   0.000000   0.000000       0.000000
# 11  20.333333    7.000000    15.900000   0.333333   0.000000       0.000000
# ..        ...         ...          ...        ...        ...            ...
# 47  15.333333    4.000000    16.300000   0.000000   0.666667       0.666667
# 48  18.333333    3.666667    16.566667   0.333333   0.666667       0.666667
# 49  19.000000    4.666667    16.633333   0.333333   0.666667       0.666667
# 50  15.333333    5.000000    16.366667   0.666667   0.000000       0.000000
# 51  19.000000    6.666667    14.833333   0.666667   0.000000       0.000000
#
# [107 rows x 41 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# C:\Users\hymys\AppData\Local\Temp\ipykernel_11396\4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 3  2022-08-27  17:30  Premier League   Matchweek 4
#                         4  2022-08-31  19:30  Premier League   Matchweek 5
#                         5  2022-09-04  16:30  Premier League   Matchweek 6
#                         7  2022-09-18  12:00  Premier League   Matchweek 8
#                         8  2022-10-01  12:30  Premier League   Matchweek 9
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 34 2025-04-01  19:45  Premier League  Matchweek 30
#                         35 2025-04-05  15:00  Premier League  Matchweek 31
#                         36 2025-04-13  14:00  Premier League  Matchweek 32
#                         37 2025-04-20  14:00  Premier League  Matchweek 33
#                         38 2025-04-26  15:00  Premier League  Matchweek 34
#
#                             day venue result   gf   ga        opponent  ...  \
# team                                                                    ...
# Arsenal                 3   Sat  Home      W  2.0  1.0          Fulham  ...
#                         4   Wed  Home      W  2.0  1.0     Aston Villa  ...
#                         5   Sun  Away      L  1.0  3.0  Manchester Utd  ...
#                         7   Sun  Away      W  3.0  0.0       Brentford  ...
#                         8   Sat  Home      W  3.0  1.0       Tottenham  ...
# ...                         ...   ...    ...  ...  ...             ...  ...
# Wolverhampton Wanderers 34  Tue  Home      W  1.0  0.0        West Ham  ...
#                         35  Sat  Away      W  2.0  1.0    Ipswich Town  ...
#                         36  Sun  Home      W  4.0  2.0       Tottenham  ...
#                         37  Sun  Away      W  1.0  0.0  Manchester Utd  ...
#                         38  Sat  Home      W  3.0  0.0  Leicester City  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 3          5       1    3.000000    0.666667
#                         4          2       1    3.000000    1.000000
#                         5          6       0    2.333333    0.666667
#                         7          6       1    1.666667    1.666667
#                         8          5       1    2.000000    1.333333
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 34         1       1    1.333333    1.333333
#                         35         5       1    1.333333    0.666667
#                         36         6       1    1.666667    0.666667
#                         37         6       1    2.333333    1.000000
#                         38         5       1    2.333333    1.000000
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 3   14.333333    5.000000    14.133333   0.333333
#                         4   18.333333    7.000000    14.433333   0.333333
#                         5   19.333333    7.333333    15.533333   0.666667
#                         7   20.000000    6.333333    16.800000   1.000000
#                         8   17.000000    6.000000    17.700000   0.666667
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 34  11.333333    3.666667    18.233333   1.333333
#                         35   8.333333    2.666667    19.433333   0.666667
#                         36  12.000000    3.666667    17.733333   0.333333
#                         37  14.666667    4.333333    16.733333   0.666667
#                         38  13.000000    4.333333    16.433333   0.666667
#
#                            pk_rolling  pkatt_rolling
# team
# Arsenal                 3         0.0            0.0
#                         4         0.0            0.0
#                         5         0.0            0.0
#                         7         0.0            0.0
#                         8         0.0            0.0
# ...                               ...            ...
# Wolverhampton Wanderers 34        0.0            0.0
#                         35        0.0            0.0
#                         36        0.0            0.0
#                         37        0.0            0.0
#                         38        0.0            0.0
#
# [2128 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# 5  2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L  1.0
# 7  2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W  3.0
# 8  2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 34 2025-04-01  19:45  Premier League  Matchweek 30  Tue  Home      W  1.0
# 35 2025-04-05  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 36 2025-04-13  14:00  Premier League  Matchweek 32  Sun  Home      W  4.0
# 37 2025-04-20  14:00  Premier League  Matchweek 33  Sun  Away      W  1.0
# 38 2025-04-26  15:00  Premier League  Matchweek 34  Sat  Home      W  3.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 3   1.0          Fulham  ...         5       1    3.000000    0.666667
# 4   1.0     Aston Villa  ...         2       1    3.000000    1.000000
# 5   3.0  Manchester Utd  ...         6       0    2.333333    0.666667
# 7   0.0       Brentford  ...         6       1    1.666667    1.666667
# 8   1.0       Tottenham  ...         5       1    2.000000    1.333333
# ..  ...             ...  ...       ...     ...         ...         ...
# 34  0.0        West Ham  ...         1       1    1.333333    1.333333
# 35  1.0    Ipswich Town  ...         5       1    1.333333    0.666667
# 36  2.0       Tottenham  ...         6       1    1.666667    0.666667
# 37  0.0  Manchester Utd  ...         6       1    2.333333    1.000000
# 38  0.0  Leicester City  ...         5       1    2.333333    1.000000
#
#    sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 3   14.333333    5.000000    14.133333   0.333333        0.0            0.0
# 4   18.333333    7.000000    14.433333   0.333333        0.0            0.0
# 5   19.333333    7.333333    15.533333   0.666667        0.0            0.0
# 7   20.000000    6.333333    16.800000   1.000000        0.0            0.0
# 8   17.000000    6.000000    17.700000   0.666667        0.0            0.0
# ..        ...         ...          ...        ...        ...            ...
# 34  11.333333    3.666667    18.233333   1.333333        0.0            0.0
# 35   8.333333    2.666667    19.433333   0.666667        0.0            0.0
# 36  12.000000    3.666667    17.733333   0.333333        0.0            0.0
# 37  14.666667    4.333333    16.733333   0.666667        0.0            0.0
# 38  13.000000    4.333333    16.433333   0.666667        0.0            0.0
#
# [2128 rows x 41 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 1    2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# 2    2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L  1.0
# 3    2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W  3.0
# 4    2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 2123 2025-04-01  19:45  Premier League  Matchweek 30  Tue  Home      W  1.0
# 2124 2025-04-05  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 2125 2025-04-13  14:00  Premier League  Matchweek 32  Sun  Home      W  4.0
# 2126 2025-04-20  14:00  Premier League  Matchweek 33  Sun  Away      W  1.0
# 2127 2025-04-26  15:00  Premier League  Matchweek 34  Sat  Home      W  3.0
#
#        ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0     1.0          Fulham  ...         5       1    3.000000    0.666667
# 1     1.0     Aston Villa  ...         2       1    3.000000    1.000000
# 2     3.0  Manchester Utd  ...         6       0    2.333333    0.666667
# 3     0.0       Brentford  ...         6       1    1.666667    1.666667
# 4     1.0       Tottenham  ...         5       1    2.000000    1.333333
# ...   ...             ...  ...       ...     ...         ...         ...
# 2123  0.0        West Ham  ...         1       1    1.333333    1.333333
# 2124  1.0    Ipswich Town  ...         5       1    1.333333    0.666667
# 2125  2.0       Tottenham  ...         6       1    1.666667    0.666667
# 2126  0.0  Manchester Utd  ...         6       1    2.333333    1.000000
# 2127  0.0  Leicester City  ...         5       1    2.333333    1.000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 0     14.333333    5.000000    14.133333   0.333333        0.0            0.0
# 1     18.333333    7.000000    14.433333   0.333333        0.0            0.0
# 2     19.333333    7.333333    15.533333   0.666667        0.0            0.0
# 3     20.000000    6.333333    16.800000   1.000000        0.0            0.0
# 4     17.000000    6.000000    17.700000   0.666667        0.0            0.0
# ...         ...         ...          ...        ...        ...            ...
# 2123  11.333333    3.666667    18.233333   1.333333        0.0            0.0
# 2124   8.333333    2.666667    19.433333   0.666667        0.0            0.0
# 2125  12.000000    3.666667    17.733333   0.333333        0.0            0.0
# 2126  14.666667    4.333333    16.733333   0.666667        0.0            0.0
# 2127  13.000000    4.333333    16.433333   0.666667        0.0            0.0
#
# [2128 rows x 41 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2025-01-01']
    test = data[data["date"] > '2025-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5138888888888888

# %%
combined
# Out:
#       actual  predicted
# 92         0          1
# 93         1          0
# 94         0          0
# 95         1          0
# 96         1          0
# ...      ...        ...
# 2123       1          0
# 2124       1          0
# 2125       1          1
# 2126       1          0
# 2127       1          0
#
# [302 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 92         0          1 2025-01-04                  Arsenal         Brighton
# 93         1          0 2025-01-15                  Arsenal        Tottenham
# 94         0          0 2025-01-18                  Arsenal      Aston Villa
# 95         1          0 2025-01-25                  Arsenal           Wolves
# 96         1          0 2025-02-02                  Arsenal  Manchester City
# ...      ...        ...        ...                      ...              ...
# 2123       1          0 2025-04-01  Wolverhampton Wanderers         West Ham
# 2124       1          0 2025-04-05  Wolverhampton Wanderers     Ipswich Town
# 2125       1          1 2025-04-13  Wolverhampton Wanderers        Tottenham
# 2126       1          0 2025-04-20  Wolverhampton Wanderers   Manchester Utd
# 2127       1          0 2025-04-26  Wolverhampton Wanderers   Leicester City
#
#      result
# 92        D
# 93        W
# 94        D
# 95        W
# 96        W
# ...     ...
# 2123      W
# 2124      W
# 2125      W
# 2126      W
# 2127      W
#
# [302 rows x 6 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)


combined["new_team"] = combined["team"].map(mapping)

merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    33
# 0    31
# Name: count, dtype: int64
